# %% [markdown]
# # Task 4.7 Deriving New Variables
# 1. Creating 'price_label' and 'busiest day' columns
# 2. Creating two 'busiest days' and two 'slowest days' columns
# 3. Checking values for accuracy
# 4. Creating Busiest_period_of_day column with labels: 'most orders', 'Average orders' & 'Fewest orders' labels
# 5. Frequency for Busiest_period_of_day column print
# 6. Exporting Dataframe as pickle file

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Creating path
path = r'C:\Users\terry\Documents\Data Analytics Course\Achievement 4\23-11-2024 Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
# Creating a subset of the dataframe ords_prods_merge
df = ords_prods_merge[ :1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %% [markdown]
# # Creating Price_label Column for Dataframe subset

# %%
# Define a Function

def price_label(row):
    if row['prices'] <=5:
        return 'Low range product'
    elif (row['prices'] > 5) and (row['prices'] <=15):
        return 'mid range product'
    elif row['prices'] > 15:
        return 'High range product'
    else: return np.nan

# %%
# Apply the function

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\terry\AppData\Local\Temp\ipykernel_7024\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
  df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# mid range product     673340
# Low range product     314392
# High range product     12268
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 25.0

# %% [markdown]
# ## Using If-Statements with the loc() function to entire dataframe

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <=5) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <=5, 'price_range_loc'] = 'Low range product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# NaN                   21865987
# Low range product     10126321
# High range product      412551
# Name: count, dtype: int64

# %%
# Creating busiest day of the week
ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []

for value in ords_prods_merge["orders_day_of_week"]:
    if value == 0:
        result.append("Busiest day")
    elif value == 4:
        result.append("Least busy day")
    else:
        result.append("Regularly busy day")

# %%
result
# Out:
# ['Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Least busy day',
#  'Least busy day',
#  'Least busy day',
#  'Least busy day',
#  'Least busy day',
#  'Least busy day',
#  'Least busy day',
#  'Least busy day',
#  'Least busy day',
#  'Least busy day',
#  'Least busy day',
#  'Least busy day',
#  'Least busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
# ...

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy day    22416875
# Busiest day            6204182
# Least busy day         3783802
# Name: count, dtype: int64

# %% [markdown]
# # Step 2
# ## Updating 'Busiest day' column to two 'busiest days' of the week  aswell as creating a new column for 2 'slowest days' of the week

# %%
result_2 = []
for value in ords_prods_merge["orders_day_of_week"]:
    if value == 0 or value == 1:
        result_2.append("Busiest days")
    elif value == 4 or value == 3:
        result_2.append("Slowest days")
    else:
        result_2.append("Regularly busy")

# %%
result_2
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
# ...

# %% [markdown]
# ## Step 3: Checking for values of 'Busiest days' updated column for accuracy

# %%
# Creating newly updated column for 'Busiest days' in the ords_prods_merge dataframe for results

# %%
ords_prods_merge['busiest_days'] = result_2

# %%
ords_prods_merge['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: count, dtype: int64

# %%
# Checking results with "Busiest days" column
ords_prods_merge.head()
# Out:
#    order_id  user_id  number_of_order  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1                1                   2                  8
# 1   2539329        1                1                   2                  8
# 2   2539329        1                1                   2                  8
# 3   2539329        1                1                   2                  8
# 4   2539329        1                1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %% [markdown]
# The overall row counts of the entire dataframe matches the number of days on the ords_prods_merge dataframe. Breaking it down on the orders_day_of_week, 0 and 1 represent the two busiest days of week and their sum ( 6204182 + 5660230) matches the newly created 'Busiest days'column total of 11864412.

# %% [markdown]
# # Step 4
# ### Creating 'Busiest_period_of_day' column with labels: 'Most oders', 'Average orders' and 'Fewest orders'

# %%
# Checking value counts in 'order_hour_of_day' column
ords_prods_merge['order_hour_of_day'].value_counts()
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %% [markdown]
# Most orders are done during the following hours: 10, 11, 14, 15, 13, 12, 16, 9. Average orders during the hours of 17, 8, 18, 19, 20, 7, 21, 22. All other Hours have fewer orders.

# %%
result_3 = []

for value in ords_prods_merge["order_hour_of_day"]:
    if value in [10, 11, 14, 15, 13, 12, 16, 9]:
        result_3.append("Most orders")
    elif value in [17, 8, 18, 19, 20, 7, 21, 22]:
        result_3.append("Average orders")
    else:
        result_3.append("Fewest orders")

# %%
result_3
# Out:
# ['Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
# ...

# %%
# Creating new column "busiest_period_of_day' in ords_prods_merge dataframe

# %%
ords_prods_merge['busiest_period_of_day'] = result_3

# %% [markdown]
# # Step 5
# ## Printing frequency of 'busiest_period_of_day' column in ord_prods_merge dataframe

# %%
# Print value counts in 'Busiest_period_of_day' column

ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: count, dtype: int64

# %%
# Checking ords_prods_merge with new columns
ords_prods_merge.head()
# Out:
#    order_id  user_id  number_of_order  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1                1                   2                  8
# 1   2539329        1                1                   2                  8
# 2   2539329        1                1                   2                  8
# 3   2539329        1                1                   2                  8
# 4   2539329        1                1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %% [markdown]
# Since clients changed their changed their minds from wanting to know the 'Busiest day' to 'Busiest days', the 'Busiest day' column becomes obsolete and i will be deleting that column in the final ords_prods_merge dataframe before exporting.

# %%
ords_prods_merge = ords_prods_merge.drop('busiest_day', axis=1)

# %%
# Checking if 'busiest_day' column has been dropped
ords_prods_merge.head()
# Out:
#    order_id  user_id  number_of_order  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1                1                   2                  8
# 1   2539329        1                1                   2                  8
# 2   2539329        1                1                   2                  8
# 3   2539329        1                1                   2                  8
# 4   2539329        1                1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %% [markdown]
# # Step 7
# ### Exporting dataframe in pickle format to 'Prepared Data'

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_updated.pkl'))
