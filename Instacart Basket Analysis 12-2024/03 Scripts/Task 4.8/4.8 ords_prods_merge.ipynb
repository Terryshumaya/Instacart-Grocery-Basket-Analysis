# %% [markdown]
# # Exercise 4.8 Grouping Data and Aggregating Variables

# %% [markdown]
# ## 1. Importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2. Importing ords_prods_merge Dataframe

# %%
# Creating path
path = r'C:\Users\terry\Documents\Data Analytics Course\Achievement 4\23-11-2024 Instacart Basket Analysis'

# %%
# importing data
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %% [markdown]
# ## 3. Creating ords_prods_merge dataframe subset 'df'

# %%
# Creating a subset df
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %%
df.head()
# Out:
#    order_id  user_id  number_of_order  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1                1                   2                  8
# 1   2539329        1                1                   2                  8
# 2   2539329        1                1                   2                  8
# 3   2539329        1                1                   2                  8
# 4   2539329        1                1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %% [markdown]
# ### Using 'groupby' and 'agg' functions to determine mean of 'number_of_order'

# %%
df.groupby('department_id')['number_of_order'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: number_of_order, dtype: float64

# %%
df.groupby('department_id').agg({'number_of_order': ['mean', 'min', 'max']})
# Out:
#               number_of_order
#                          mean min max
# department_id
# 1                   14.800024   1  99
# 2                   17.091743   1  98
# 3                   17.913544   1  99
# 4                   17.893092   1  99
# 5                   15.214270   1  99
# 6                   15.382135   1  99
# 7                   17.694027   1  99
# 8                   16.458105   1  91
# 9                   15.957363   1  99
# 10                  20.091818   1  99
# 11                  16.482026   1  99
# 12                  15.615061   1  99
# 13                  16.484023   1  99
# 14                  17.524632   1  99
# 15                  15.691875   1  99
# 16                  18.014071   1  99
# 17                  16.150593   1  99
# 18                  19.602850   1  99
# 19                  17.631340   1  99
# 20                  17.138607   1  99
# 21                  21.956893   1  97

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['number_of_order'].transform(np.max)
# Out:
# C:\Users\terry\AppData\Local\Temp\ipykernel_5376\506111299.py:1: FutureWarning: The provided callable <function max at 0x0000029C2A838680> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['number_of_order'].transform(np.max)

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  number_of_order  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1                1                   2                  8
# 1    2539329        1                1                   2                  8
# 2    2539329        1                1                   2                  8
# 3    2539329        1                1                   2                  8
# 4    2539329        1                1                   2                  8
# ..       ...      ...              ...                 ...                ...
# 95    738281        2                4                   2                 10
# 96   1673511        2                5                   3                 11
# 97   1673511        2                5                   3                 11
# 98   1673511        2                5                   3                 11
# 99   1673511        2                5                   3                 11
#
# ...

# %%
# Function to display all rows
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <=10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'number_of_order', 'max_order']].head(60)
# Out:
#     user_id      loyalty_flag  number_of_order  max_order
# 0         1      New customer                1         10
# 1         1      New customer                1         10
# 2         1      New customer                1         10
# 3         1      New customer                1         10
# 4         1      New customer                1         10
# 5         1      New customer                2         10
# 6         1      New customer                2         10
# 7         1      New customer                2         10
# 8         1      New customer                2         10
# 9         1      New customer                2         10
# 10        1      New customer                2         10
# 11        1      New customer                3         10
# 12        1      New customer                3         10
# 13        1      New customer                3         10
# 14        1      New customer                3         10
# ...
